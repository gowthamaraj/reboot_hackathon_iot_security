# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

df = pd.read_csv('network.CSV')

# %%
df.head()
# Out:
#    No.      Time             Source        Destination Protocol  Length  \
# 0    1  0.000000      172.16.23.109      172.16.23.255      UDP      62
# 1    2  0.000003      172.16.23.109      172.16.23.255      UDP      62
# 2    3  0.008023  NubiaTec_96:7d:85  ZebraTec_f0:f0:04   0x8781      74
# 3    4  0.008143       172.16.21.59      172.16.23.255      UDP      62
# 4    5  0.008672       172.16.21.59      172.16.23.255      UDP      62
#
#                    Info
# 0  2008  >  2008 Len=20
# 1  2007  >  2007 Len=20
# 2           Ethernet II
# 3  2008  >  2008 Len=20
# 4  2007  >  2007 Len=20

# %%
plt.plot(df['Protocol'])

# %%
plt.scatter(df['Length'],df['Protocol'])
